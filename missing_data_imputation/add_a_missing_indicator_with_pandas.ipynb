# %% [markdown]
# ## Missing indicator
#
# - A binary variable that indicates whether a value is missing.
#
# - Useful for both numerical and categorical features, and often paired with other imputation methods rather than used alone.
#
# ### Assumptions:
#
# - Use with mean, median, mode imputation, random sample imputation (Data is **missing at random**)
#
# ### Considerations
#
# - Expands the feature space
#
# - Original variable still needs to be imputed
#
# - Many missing indicators may end up being identical or very highly correlated

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

TEST_SIZE = 0.3
RANDOM_STATE = 44

# %%
cols_to_use = [
    "OverallQual",
    "TotalBsmtSF",
    "1stFlrSF",
    "GrLivArea",
    "WoodDeckSF",
    "BsmtUnfSF",
    "LotFrontage",
    "MasVnrArea",
    "GarageYrBlt",
    "BsmtQual",
    "FireplaceQu",
    "SalePrice"
]

# %%
data = pd.read_csv("../data/houseprice.csv", usecols=cols_to_use)
data.head()
# Out:
#    LotFrontage  OverallQual  MasVnrArea BsmtQual  BsmtUnfSF  TotalBsmtSF  \
# 0         65.0            7       196.0       Gd        150          856
# 1         80.0            6         0.0       Gd        284         1262
# 2         68.0            7       162.0       Gd        434          920
# 3         60.0            7         0.0       TA        540          756
# 4         84.0            8       350.0       Gd        490         1145
#
#    1stFlrSF  GrLivArea FireplaceQu  GarageYrBlt  WoodDeckSF  SalePrice
# 0       856       1710         NaN       2003.0           0     208500
# 1      1262       1262          TA       1976.0         298     181500
# 2       920       1786          TA       2001.0           0     223500
# 3       961       1717          Gd       1998.0           0     140000
# 4      1145       2198          TA       2000.0         192     250000

# %%
# Split into train and test set before imputing, as a good practice to reduce overfitting due to data leaks
X_train, X_test, y_train, y_test = train_test_split(
    data.drop('SalePrice', axis=1),
    data['SalePrice'],
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE
)

X_train.shape, X_test.shape
# Out:
# ((1022, 11), (438, 11))

# %%
# Capture numerical variables
vars_num = list(data.select_dtypes(include="number").columns)
vars_num
# Out:
# ['LotFrontage',
#  'OverallQual',
#  'MasVnrArea',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'GrLivArea',
#  'GarageYrBlt',
#  'WoodDeckSF',
#  'SalePrice']

# %%
# Capture categorical variables
vars_cat = list(data.select_dtypes(exclude="number").columns)
vars_cat
# Out:
# ['BsmtQual', 'FireplaceQu']

# %%
# Create imputation dict
imputation_dict = data[vars_num].median().to_dict()
imputation_dict.update(data[vars_cat].mode().iloc[0].to_dict())
imputation_dict
# Out:
# {'LotFrontage': 69.0,
#  'OverallQual': 6.0,
#  'MasVnrArea': 0.0,
#  'BsmtUnfSF': 477.5,
#  'TotalBsmtSF': 991.5,
#  '1stFlrSF': 1087.0,
#  'GrLivArea': 1464.0,
#  'GarageYrBlt': 1980.0,
#  'WoodDeckSF': 0.0,
#  'SalePrice': 163000.0,
#  'BsmtQual': 'TA',
#  'FireplaceQu': 'Gd'}

# %%
# Create indicator features' name
indicators = [f"{var}_na" for var in X_train.columns]
indicators
# Out:
# ['LotFrontage_na',
#  'OverallQual_na',
#  'MasVnrArea_na',
#  'BsmtQual_na',
#  'BsmtUnfSF_na',
#  'TotalBsmtSF_na',
#  '1stFlrSF_na',
#  'GrLivArea_na',
#  'FireplaceQu_na',
#  'GarageYrBlt_na',
#  'WoodDeckSF_na']

# %%
# add na indicators to X_train, X_test
X_train[indicators] = X_train.isna().astype(int)
X_test[indicators] = X_test.isna().astype(int)

print(X_train.head())
print(X_test.head())
# Out:
#       LotFrontage  OverallQual  MasVnrArea BsmtQual  BsmtUnfSF  TotalBsmtSF  \
# 146          51.0            5         0.0       TA        506          715
# 1115         93.0            8       328.0       Ex        730         1734
# 758          24.0            7       360.0       Gd        195          744
# 280          82.0            7       340.0       Gd        386          807
# 1340         70.0            4         0.0       TA        858          858
#
#       1stFlrSF  GrLivArea FireplaceQu  GarageYrBlt  ...  OverallQual_na  \
# 146        875        875         NaN       1931.0  ...               0
# 1115      1734       1734          Gd       2007.0  ...               0
# 758        757       1501         NaN       1999.0  ...               0
# 280       1175       1982          TA       1989.0  ...               0
# 1340       872        872         NaN       1974.0  ...               0
#
#       MasVnrArea_na  BsmtQual_na  BsmtUnfSF_na  TotalBsmtSF_na  1stFlrSF_na  \
# 146               0            0             0               0            0
# 1115              0            0             0               0            0
# 758               0            0             0               0            0
# 280               0            0             0               0            0
# 1340              0            0             0               0            0
#
#       GrLivArea_na  FireplaceQu_na  GarageYrBlt_na  WoodDeckSF_na
# 146              0               1               0              0
# 1115             0               0               0              0
# 758              0               1               0              0
# 280              0               0               0              0
# 1340             0               1               0              0
#
# [5 rows x 22 columns]
#       LotFrontage  OverallQual  MasVnrArea BsmtQual  BsmtUnfSF  TotalBsmtSF  \
# 1140         60.0            5         0.0       TA        100          952
# 132          75.0            5         0.0       TA        658         1063
# 642          75.0            8         0.0       Gd        542         1952
# 952          60.0            5         0.0       Gd        108          768
# 1297         35.0            6        82.0       Gd          0          547
#
#       1stFlrSF  GrLivArea FireplaceQu  GarageYrBlt  ...  OverallQual_na  \
# 1140       952        952         NaN       1988.0  ...               0
# 132       1327       1327         NaN       1974.0  ...               0
# 642       2000       2704          TA       1972.0  ...               0
# 952        768        768         NaN       1974.0  ...               0
# 1297      1072       1072         NaN       2005.0  ...               0
#
#       MasVnrArea_na  BsmtQual_na  BsmtUnfSF_na  TotalBsmtSF_na  1stFlrSF_na  \
# 1140              0            0             0               0            0
# 132               0            0             0               0            0
# 642               0            0             0               0            0
# 952               0            0             0               0            0
# 1297              0            0             0               0            0
#
#       GrLivArea_na  FireplaceQu_na  GarageYrBlt_na  WoodDeckSF_na
# 1140             0               1               0              0
# 132              0               1               0              0
# 642              0               0               0              0
# 952              0               1               0              0
# 1297             0               1               0              0
#
# [5 rows x 22 columns]

# %%
# fill missing data with imputation dict
X_train.fillna(imputation_dict, inplace=True)
X_test.fillna(imputation_dict, inplace=True)

# %%
X_train.isna().sum()
# Out:
# LotFrontage       0
# OverallQual       0
# MasVnrArea        0
# BsmtQual          0
# BsmtUnfSF         0
# TotalBsmtSF       0
# 1stFlrSF          0
# GrLivArea         0
# FireplaceQu       0
# GarageYrBlt       0
# WoodDeckSF        0
# LotFrontage_na    0
# OverallQual_na    0
# MasVnrArea_na     0
# BsmtQual_na       0
# BsmtUnfSF_na      0
# TotalBsmtSF_na    0
# 1stFlrSF_na       0
# GrLivArea_na      0
# FireplaceQu_na    0
# GarageYrBlt_na    0
# WoodDeckSF_na     0
# dtype: int64

# %%
X_test.isna().sum()
# Out:
# LotFrontage       0
# OverallQual       0
# MasVnrArea        0
# BsmtQual          0
# BsmtUnfSF         0
# TotalBsmtSF       0
# 1stFlrSF          0
# GrLivArea         0
# FireplaceQu       0
# GarageYrBlt       0
# WoodDeckSF        0
# LotFrontage_na    0
# OverallQual_na    0
# MasVnrArea_na     0
# BsmtQual_na       0
# BsmtUnfSF_na      0
# TotalBsmtSF_na    0
# 1stFlrSF_na       0
# GrLivArea_na      0
# FireplaceQu_na    0
# GarageYrBlt_na    0
# WoodDeckSF_na     0
# dtype: int64
